# %% [markdown]
# # Seattle Airbnb Listings
#
# ## A preliminary look

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("Done")
# Out:
# Done

# %%
pwd
# Out:
# '/Users/sukanto/Google Drive/allprojects/Seattle_Airbnb/Seattle-Airbnb'

# %% [markdown]
# # Reading in Data and Preprocessing

# %% [markdown]
# ## Listings Data

# %%
tic = time.time()
df = pd.read_csv('calendar.csv') #reading in first csv file of calendar
toc = time.time() - tic
print("Time taken to load it up %s seconds" %(toc))
df.head()
# Out:
# Time taken to load it up 0.6734929084777832 seconds
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
df.isnull().any() #checking for missing values in columns
# Out:
# listing_id    False
# date          False
# available     False
# price          True
# dtype: bool

# %%
df['price'].isna().sum() #checking for total missing values
# Out:
# 459028

# %%
df.shape #looking at data dimensions
# Out:
# (1393570, 4)

# %%
df['price'].describe() #looking at summary stats of price column
# Out:
# count      934542
# unique        669
# top       $150.00
# freq        36646
# Name: price, dtype: object

# %%
tic = time.time()
df['price'] = df['price'].str.replace("[$,]", "").astype("float")
toc = time.time() - tic
print("Time taken %s seconds" %(toc)) #convert price data points to float; see how the code might be performing
# Out:
# Time taken 1.2116680145263672 seconds

# %%
df.head()
# Out:
#    listing_id        date available  price
# 0      241032  2016-01-04         t   85.0
# 1      241032  2016-01-05         t   85.0
# 2      241032  2016-01-06         f    NaN
# 3      241032  2016-01-07         f    NaN
# 4      241032  2016-01-08         f    NaN

# %%
df_price = df.fillna(df['price'].median()) #imputing missing values in price with median values
df_price.head()
# Out:
#    listing_id        date available  price
# 0      241032  2016-01-04         t   85.0
# 1      241032  2016-01-05         t   85.0
# 2      241032  2016-01-06         f  109.0
# 3      241032  2016-01-07         f  109.0
# 4      241032  2016-01-08         f  109.0

# %%
df_price['price'].median() #middle point of price
# Out:
# 109.0

# %%
plt.figure(figsize=(20,10))
plt.hist(df_price['price'],bins=20)
plt.xlabel('Prices')
plt.savefig('listing_prices.jpg'); #most prices stay within the $250 range

# %%
df_50 = df_price[:50]
df_50.head()
# Out:
#    listing_id        date available  price
# 0      241032  2016-01-04         t   85.0
# 1      241032  2016-01-05         t   85.0
# 2      241032  2016-01-06         f  109.0
# 3      241032  2016-01-07         f  109.0
# 4      241032  2016-01-08         f  109.0

# %%
df_50.shape
# Out:
# (50, 4)

# %%
#preliminary availability vs price

tic = time.time()
plt.figure(figsize=(20,20))
sns.barplot(df_50['available'],df_50['price'])
plt.xlabel('Availability')
plt.ylabel('Price')
plt.title('Overall availability vs Price')
plt.savefig('av_pr.jpg')
toc = time.time() - tic
print("Time taken to generate this graph: %s seconds."%(toc))
# Out:
# Time taken to generate this graph: 0.27392077445983887 seconds.

# %%
df_p = df_price[df_price['available']!='f']
df_p.drop(['listing_id'],axis=1,inplace=True)
df_p
# Out:
# /Users/sukanto/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                date available  price
# 0        2016-01-04         t   85.0
# 1        2016-01-05         t   85.0
# 9        2016-01-13         t   85.0
# 10       2016-01-14         t   85.0
# 14       2016-01-18         t   85.0
# ...             ...       ...    ...
# 1393207  2016-01-06         t   87.0
# 1393208  2016-01-07         t   87.0
# 1393211  2016-01-10         t   87.0
# 1393212  2016-01-11         t   87.0
# 1393213  2016-01-12         t   87.0
#
# [934542 rows x 3 columns]

# %%
df_p_1 = df_p[['date','price']]
df_p_1
# Out:
#                date  price
# 0        2016-01-04   85.0
# 1        2016-01-05   85.0
# 9        2016-01-13   85.0
# 10       2016-01-14   85.0
# 14       2016-01-18   85.0
# ...             ...    ...
# 1393207  2016-01-06   87.0
# 1393208  2016-01-07   87.0
# 1393211  2016-01-10   87.0
# 1393212  2016-01-11   87.0
# 1393213  2016-01-12   87.0
#
# [934542 rows x 2 columns]

# %%
df_p_1.to_csv('prices.csv')

# %%
points = df_p_1[['date','price']].head(500)
points
# Out:
#            date  price
# 0    2016-01-04   85.0
# 1    2016-01-05   85.0
# 9    2016-01-13   85.0
# 10   2016-01-14   85.0
# 14   2016-01-18   85.0
# ..          ...    ...
# 588  2016-08-14  206.0
# 589  2016-08-15  187.0
# 590  2016-08-16  185.0
# 591  2016-08-17  189.0
# 592  2016-08-18  195.0
#
# [500 rows x 2 columns]

# %%
points.columns
# Out:
# Index(['date', 'price'], dtype='object')

# %%
points.plot()
plt.savefig('date_price.jpg');

# %% [markdown]
# ## Listings Data

# %%
tic = time.time()
df1 = pd.read_csv('listings.csv')
toc = time.time() - tic
print("Time taken to load this up %s seconds" %(toc))  #reading in listings dataframe
df1.head()
# Out:
# Time taken to load this up 0.3064157962799072 seconds
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                10.0
# 1  Queen Anne is a wonderful, truly functional vi...  ...                10.0
# 2  Upper Queen Anne is a charming neighborhood fu...  ...                10.0
# 3                                                NaN  ...                 NaN
# 4  We are in the beautiful neighborhood of Queen ...  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN         WASHINGTON                f
# 1                f     NaN         WASHINGTON                f
# 2                f     NaN         WASHINGTON                f
# 3                f     NaN         WASHINGTON                f
# 4                f     NaN         WASHINGTON                f
#
#   cancellation_policy  require_guest_profile_picture  \
# 0            moderate                              f
# 1              strict                              t
# 2              strict                              f
# 3            flexible                              f
# 4              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
df1.shape
# Out:
# (3818, 92)

# %%
df1.columns #looking at dataframe columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
df1.drop(['listing_url','scrape_id','notes','jurisdiction_names','thumbnail_url','medium_url'],axis=1,inplace=True)

# %%
df1.isnull().any() #checking for missing values
# Out:
# id                                  False
# last_scraped                        False
# name                                False
# summary                              True
# space                                True
#                                     ...
# cancellation_policy                 False
# require_guest_profile_picture       False
# require_guest_phone_verification    False
# calculated_host_listings_count      False
# reviews_per_month                    True
# Length: 86, dtype: bool

# %%
df1['reviews_per_month'] = df1['reviews_per_month'].fillna(df1['reviews_per_month'].median()) #filling missing values in reviews per month with median
df1.head()
# Out:
#         id last_scraped                                 name  \
# 0   241032   2016-01-04         Stylish Queen Anne Apartment
# 1   953595   2016-01-04   Bright & Airy Queen Anne Apartment
# 2  3308979   2016-01-04  New Modern House-Amazing water view
# 3  7421966   2016-01-04                   Queen Anne Chateau
# 4   278830   2016-01-04       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
# 3                                                NaN
# 4  We are in the beautiful neighborhood of Queen ...
#
#                                              transit  \
# 0                                                NaN
# 1  Convenient bus stops are just down the block, ...
# 2  A bus stop is just 2 blocks away.   Easy bus a...
# 3                                                NaN
# 4  The nearest public transit bus (D Line) is 2 b...
#
#                                          picture_url  ...  \
# 0  https://a1.muscache.com/ac/pictures/67560560/c...  ...
# 1  https://a0.muscache.com/ac/pictures/14409893/f...  ...
# 2  https://a2.muscache.com/ac/pictures/b4324e0f-a...  ...
# 3  https://a0.muscache.com/ac/pictures/94146944/6...  ...
# 4  https://a1.muscache.com/ac/pictures/6120468/b0...  ...
#
#   review_scores_location  review_scores_value requires_license license  \
# 0                    9.0                 10.0                f     NaN
# 1                   10.0                 10.0                f     NaN
# 2                   10.0                 10.0                f     NaN
# 3                    NaN                  NaN                f     NaN
# 4                    9.0                  9.0                f     NaN
#
#   instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                f            moderate                             f
# 1                f              strict                             t
# 2                f              strict                             f
# 3                f            flexible                             f
# 4                f              strict                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3              1.54
# 4              0.89
#
# [5 rows x 86 columns]

# %%
can = df1.cancellation_policy.value_counts() #how many listings have strict cancellation policies?
can
# Out:
# strict      1417
# moderate    1251
# flexible    1150
# Name: cancellation_policy, dtype: int64

# %%
print("Of the listings, {:.2f}% have strict cancellation policies".format((1417/sum(can))*100))
# Out:
# Of the listings, 37.11% have strict cancellation policies

# %%
plt.figure(figsize=(20,10))
(can[:20]/df1.shape[0]).plot(kind='bar')
plt.title("Cancellation policies of Top 20 Listings")
plt.savefig('can.jpg'); #looks like most listings have strict cancellation policies

# %%
df1.isnull().any()
# Out:
# id                                  False
# last_scraped                        False
# name                                False
# summary                              True
# space                                True
#                                     ...
# cancellation_policy                 False
# require_guest_profile_picture       False
# require_guest_phone_verification    False
# calculated_host_listings_count      False
# reviews_per_month                   False
# Length: 86, dtype: bool

# %%
df1['reviews_per_month'].describe() #summary stats for reviews per month
# Out:
# count    3818.000000
# mean        1.990416
# std         1.677888
# min         0.020000
# 25%         0.830000
# 50%         1.540000
# 75%         2.660000
# max        12.150000
# Name: reviews_per_month, dtype: float64

# %%
rev = df1['reviews_per_month'].value_counts() #chunk of listings receive around 2-3 reviews per month
rev
# Out:
# 1.54    637
# 1.00     70
# 2.00     45
# 0.23     24
# 0.36     21
#        ...
# 8.18      1
# 3.71      1
# 4.72      1
# 7.53      1
# 6.14      1
# Name: reviews_per_month, Length: 654, dtype: int64

# %%
df1['reviews_per_month'].describe() #one listing received 12 reviews a month! must be very popular
# Out:
# count    3818.000000
# mean        1.990416
# std         1.677888
# min         0.020000
# 25%         0.830000
# 50%         1.540000
# 75%         2.660000
# max        12.150000
# Name: reviews_per_month, dtype: float64

# %%
df1.drop(['license'],axis=1,inplace=True) #license columns seems to have only NaN values, thus dropping

# %%
df1.head()
# Out:
#         id last_scraped                                 name  \
# 0   241032   2016-01-04         Stylish Queen Anne Apartment
# 1   953595   2016-01-04   Bright & Airy Queen Anne Apartment
# 2  3308979   2016-01-04  New Modern House-Amazing water view
# 3  7421966   2016-01-04                   Queen Anne Chateau
# 4   278830   2016-01-04       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
# 3                                                NaN
# 4  We are in the beautiful neighborhood of Queen ...
#
#                                              transit  \
# 0                                                NaN
# 1  Convenient bus stops are just down the block, ...
# 2  A bus stop is just 2 blocks away.   Easy bus a...
# 3                                                NaN
# 4  The nearest public transit bus (D Line) is 2 b...
#
#                                          picture_url  ...  \
# 0  https://a1.muscache.com/ac/pictures/67560560/c...  ...
# 1  https://a0.muscache.com/ac/pictures/14409893/f...  ...
# 2  https://a2.muscache.com/ac/pictures/b4324e0f-a...  ...
# 3  https://a0.muscache.com/ac/pictures/94146944/6...  ...
# 4  https://a1.muscache.com/ac/pictures/6120468/b0...  ...
#
#   review_scores_communication  review_scores_location review_scores_value  \
# 0                        10.0                     9.0                10.0
# 1                        10.0                    10.0                10.0
# 2                        10.0                    10.0                10.0
# 3                         NaN                     NaN                 NaN
# 4                        10.0                     9.0                 9.0
#
#   requires_license instant_bookable cancellation_policy  \
# 0                f                f            moderate
# 1                f                f              strict
# 2                f                f              strict
# 3                f                f            flexible
# 4                f                f              strict
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count reviews_per_month
# 0                              2              4.07
# 1                              6              1.48
# 2                              2              1.15
# 3                              1              1.54
# 4                              1              0.89
#
# [5 rows x 85 columns]

# %%
df1.rename(columns={'neighborhood_overview':'neighborhood'}) #renaming a column
# Out:
#             id last_scraped                                 name  \
# 0       241032   2016-01-04         Stylish Queen Anne Apartment
# 1       953595   2016-01-04   Bright & Airy Queen Anne Apartment
# 2      3308979   2016-01-04  New Modern House-Amazing water view
# 3      7421966   2016-01-04                   Queen Anne Chateau
# 4       278830   2016-01-04       Charming craftsman 3 bdm house
# ...        ...          ...                                  ...
# 3813   8101950   2016-01-04   3BR Mountain View House in Seattle
# 3814   8902327   2016-01-04    Portage Bay View!-One Bedroom Apt
# 3815  10267360   2016-01-04    Private apartment view of Lake WA
# 3816   9604740   2016-01-04    Amazing View with Modern Comfort!
# 3817  10208623   2016-01-04            Large Lakefront Apartment
#
#                                                 summary  \
# 0                                                   NaN
# 1     Chemically sensitive? We've removed the irrita...
# 2     New modern house built in 2013.  Spectacular s...
# 3     A charming apartment that sits atop Queen Anne...
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...
# 3814  800 square foot 1 bedroom basement apartment w...
# 3815  Very comfortable lower unit. Quiet, charming m...
# 3816  Cozy studio condo in the heart on Madison Park...
# 3817  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 0     Make your self at home in this charming one-be...
# 1     Beautiful, hypoallergenic apartment in an extr...
# 2     Our house is modern, light and fresh with a wa...
# 3                                                   NaN
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house bright, stylish, and wheelch...
# 3814  This space has a great view of Portage Bay wit...
# 3815                                                NaN
# 3816  Fully furnished unit to accommodate most needs...
# 3817                                                NaN
#
#                                             description experiences_offered  \
# 0     Make your self at home in this charming one-be...                none
# 1     Chemically sensitive? We've removed the irrita...                none
# 2     New modern house built in 2013.  Spectacular s...                none
# 3     A charming apartment that sits atop Queen Anne...                none
# 4     Cozy family craftman house in beautiful neighb...                none
# ...                                                 ...                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...                none
# 3814  800 square foot 1 bedroom basement apartment w...                none
# 3815  Very comfortable lower unit. Quiet, charming m...                none
# 3816  Cozy studio condo in the heart on Madison Park...                none
# 3817  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                            neighborhood  \
# 0                                                   NaN
# 1     Queen Anne is a wonderful, truly functional vi...
# 2     Upper Queen Anne is a charming neighborhood fu...
# 3                                                   NaN
# 4     We are in the beautiful neighborhood of Queen ...
# ...                                                 ...
# 3813  We're located near lots of family fun. Woodlan...
# 3814  The neighborhood is a quiet oasis that is clos...
# 3815                                                NaN
# 3816  Madison Park offers a peaceful slow pace upsca...
# 3817                                                NaN
#
#                                                 transit  \
# 0                                                   NaN
# 1     Convenient bus stops are just down the block, ...
# 2     A bus stop is just 2 blocks away.   Easy bus a...
# 3                                                   NaN
# 4     The nearest public transit bus (D Line) is 2 b...
# ...                                                 ...
# 3813                                                NaN
# 3814  Uber and Car2go are good options in Seattle. T...
# 3815                                                NaN
# 3816                                                Yes
# 3817                                                NaN
#
#                                             picture_url  ...  \
# 0     https://a1.muscache.com/ac/pictures/67560560/c...  ...
# 1     https://a0.muscache.com/ac/pictures/14409893/f...  ...
# 2     https://a2.muscache.com/ac/pictures/b4324e0f-a...  ...
# 3     https://a0.muscache.com/ac/pictures/94146944/6...  ...
# 4     https://a1.muscache.com/ac/pictures/6120468/b0...  ...
# ...                                                 ...  ...
# 3813  https://a2.muscache.com/ac/pictures/103217071/...  ...
# 3814  https://a2.muscache.com/ac/pictures/626d4b1f-6...  ...
# 3815  https://a2.muscache.com/ac/pictures/a5974f04-2...  ...
# 3816  https://a2.muscache.com/ac/pictures/202e4ad6-b...  ...
# 3817  https://a2.muscache.com/ac/pictures/596705b3-0...  ...
#
#      review_scores_communication  review_scores_location review_scores_value  \
# 0                           10.0                     9.0                10.0
# 1                           10.0                    10.0                10.0
# 2                           10.0                    10.0                10.0
# 3                            NaN                     NaN                 NaN
# 4                           10.0                     9.0                 9.0
# ...                          ...                     ...                 ...
# 3813                         8.0                    10.0                 8.0
# 3814                        10.0                    10.0                10.0
# 3815                         NaN                     NaN                 NaN
# 3816                         NaN                     NaN                 NaN
# 3817                         NaN                     NaN                 NaN
#
#      requires_license instant_bookable cancellation_policy  \
# 0                   f                f            moderate
# 1                   f                f              strict
# 2                   f                f              strict
# 3                   f                f            flexible
# 4                   f                f              strict
# ...               ...              ...                 ...
# 3813                f                f              strict
# 3814                f                f            moderate
# 3815                f                f            moderate
# 3816                f                f            moderate
# 3817                f                f            flexible
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                t                                t
# 2                                f                                f
# 3                                f                                f
# 4                                f                                f
# ...                            ...                              ...
# 3813                             f                                f
# 3814                             f                                f
# 3815                             f                                f
# 3816                             f                                f
# 3817                             f                                f
#
#      calculated_host_listings_count reviews_per_month
# 0                                 2              4.07
# 1                                 6              1.48
# 2                                 2              1.15
# 3                                 1              1.54
# 4                                 1              0.89
# ...                             ...               ...
# 3813                              8              0.30
# 3814                              1              2.00
# 3815                              1              1.54
# 3816                              1              1.54
# 3817                              1              1.54
#
# [3818 rows x 85 columns]

# %%
df1.drop(['experiences_offered','picture_url'],axis=1,inplace=True) #dropping some more irrelevant columns

# %%
df1.head()
# Out:
#         id last_scraped                                 name  \
# 0   241032   2016-01-04         Stylish Queen Anne Apartment
# 1   953595   2016-01-04   Bright & Airy Queen Anne Apartment
# 2  3308979   2016-01-04  New Modern House-Amazing water view
# 3  7421966   2016-01-04                   Queen Anne Chateau
# 4   278830   2016-01-04       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description  \
# 0  Make your self at home in this charming one-be...
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
# 3                                                NaN
# 4  We are in the beautiful neighborhood of Queen ...
#
#                                              transit  \
# 0                                                NaN
# 1  Convenient bus stops are just down the block, ...
# 2  A bus stop is just 2 blocks away.   Easy bus a...
# 3                                                NaN
# 4  The nearest public transit bus (D Line) is 2 b...
#
#                                       xl_picture_url   host_id  ...  \
# 0                                                NaN    956883  ...
# 1  https://a0.muscache.com/ac/pictures/14409893/f...   5177328  ...
# 2                                                NaN  16708587  ...
# 3                                                NaN   9851441  ...
# 4                                                NaN   1452570  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        10.0                    9.0                10.0
# 1                        10.0                   10.0                10.0
# 2                        10.0                   10.0                10.0
# 3                         NaN                    NaN                 NaN
# 4                        10.0                    9.0                 9.0
#
#   requires_license instant_bookable cancellation_policy  \
# 0                f                f            moderate
# 1                f                f              strict
# 2                f                f              strict
# 3                f                f            flexible
# 4                f                f              strict
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count reviews_per_month
# 0                              2              4.07
# 1                              6              1.48
# 2                              2              1.15
# 3                              1              1.54
# 4                              1              0.89
#
# [5 rows x 83 columns]

# %%
df1.drop(['xl_picture_url'],axis=1,inplace=True) #and some more

# %%
df1.head()
# Out:
#         id last_scraped                                 name  \
# 0   241032   2016-01-04         Stylish Queen Anne Apartment
# 1   953595   2016-01-04   Bright & Airy Queen Anne Apartment
# 2  3308979   2016-01-04  New Modern House-Amazing water view
# 3  7421966   2016-01-04                   Queen Anne Chateau
# 4   278830   2016-01-04       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description  \
# 0  Make your self at home in this charming one-be...
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
# 3                                                NaN
# 4  We are in the beautiful neighborhood of Queen ...
#
#                                              transit   host_id  \
# 0                                                NaN    956883
# 1  Convenient bus stops are just down the block, ...   5177328
# 2  A bus stop is just 2 blocks away.   Easy bus a...  16708587
# 3                                                NaN   9851441
# 4  The nearest public transit bus (D Line) is 2 b...   1452570
#
#                                      host_url  ...  \
# 0    https://www.airbnb.com/users/show/956883  ...
# 1   https://www.airbnb.com/users/show/5177328  ...
# 2  https://www.airbnb.com/users/show/16708587  ...
# 3   https://www.airbnb.com/users/show/9851441  ...
# 4   https://www.airbnb.com/users/show/1452570  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        10.0                    9.0                10.0
# 1                        10.0                   10.0                10.0
# 2                        10.0                   10.0                10.0
# 3                         NaN                    NaN                 NaN
# 4                        10.0                    9.0                 9.0
#
#   requires_license instant_bookable cancellation_policy  \
# 0                f                f            moderate
# 1                f                f              strict
# 2                f                f              strict
# 3                f                f            flexible
# 4                f                f              strict
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count reviews_per_month
# 0                              2              4.07
# 1                              6              1.48
# 2                              2              1.15
# 3                              1              1.54
# 4                              1              0.89
#
# [5 rows x 82 columns]

# %%
df1.drop(['host_url'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#         id last_scraped                                 name  \
# 0   241032   2016-01-04         Stylish Queen Anne Apartment
# 1   953595   2016-01-04   Bright & Airy Queen Anne Apartment
# 2  3308979   2016-01-04  New Modern House-Amazing water view
# 3  7421966   2016-01-04                   Queen Anne Chateau
# 4   278830   2016-01-04       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description  \
# 0  Make your self at home in this charming one-be...
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
# 3                                                NaN
# 4  We are in the beautiful neighborhood of Queen ...
#
#                                              transit   host_id host_name  ...  \
# 0                                                NaN    956883     Maija  ...
# 1  Convenient bus stops are just down the block, ...   5177328    Andrea  ...
# 2  A bus stop is just 2 blocks away.   Easy bus a...  16708587      Jill  ...
# 3                                                NaN   9851441     Emily  ...
# 4  The nearest public transit bus (D Line) is 2 b...   1452570     Emily  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        10.0                    9.0                10.0
# 1                        10.0                   10.0                10.0
# 2                        10.0                   10.0                10.0
# 3                         NaN                    NaN                 NaN
# 4                        10.0                    9.0                 9.0
#
#   requires_license instant_bookable cancellation_policy  \
# 0                f                f            moderate
# 1                f                f              strict
# 2                f                f              strict
# 3                f                f            flexible
# 4                f                f              strict
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count reviews_per_month
# 0                              2              4.07
# 1                              6              1.48
# 2                              2              1.15
# 3                              1              1.54
# 4                              1              0.89
#
# [5 rows x 81 columns]

# %%
df1.to_csv('clean_listings.csv')

# %%
df1['instant_bookable'].value_counts() #most listings are not bookable instantly
# Out:
# f    3227
# t     591
# Name: instant_bookable, dtype: int64

# %%
df1['neighborhood_overview']
# Out:
# 0                                                     NaN
# 1       Queen Anne is a wonderful, truly functional vi...
# 2       Upper Queen Anne is a charming neighborhood fu...
# 3                                                     NaN
# 4       We are in the beautiful neighborhood of Queen ...
#                               ...
# 3813    We're located near lots of family fun. Woodlan...
# 3814    The neighborhood is a quiet oasis that is clos...
# 3815                                                  NaN
# 3816    Madison Park offers a peaceful slow pace upsca...
# 3817                                                  NaN
# Name: neighborhood_overview, Length: 3818, dtype: object

# %%
df1.columns
# Out:
# Index(['id', 'last_scraped', 'name', 'summary', 'space', 'description',
#        'neighborhood_overview', 'transit', 'host_id', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
df1[['neighbourhood_group_cleansed','has_availability','host_is_superhost','bathrooms','bedrooms','property_type','room_type',]]
# Out:
#      neighbourhood_group_cleansed has_availability host_is_superhost  \
# 0                      Queen Anne                t                 f
# 1                      Queen Anne                t                 t
# 2                      Queen Anne                t                 f
# 3                      Queen Anne                t                 f
# 4                      Queen Anne                t                 f
# ...                           ...              ...               ...
# 3813          Other neighborhoods                t                 f
# 3814                 Capitol Hill                t                 f
# 3815               Rainier Valley                t                 f
# 3816                 Capitol Hill                t                 f
# 3817                   Queen Anne                t                 f
#
#       bathrooms  bedrooms property_type        room_type
# 0           1.0       1.0     Apartment  Entire home/apt
# 1           1.0       1.0     Apartment  Entire home/apt
# 2           4.5       5.0         House  Entire home/apt
# 3           1.0       0.0     Apartment  Entire home/apt
# 4           2.0       3.0         House  Entire home/apt
# ...         ...       ...           ...              ...
# 3813        2.0       3.0         House  Entire home/apt
# 3814        1.0       1.0     Apartment  Entire home/apt
# 3815        1.0       1.0         House  Entire home/apt
# 3816        1.0       0.0   Condominium  Entire home/apt
# 3817        1.5       2.0     Apartment  Entire home/apt
#
# [3818 rows x 7 columns]

# %%
n_count = df1['neighbourhood_group_cleansed'].value_counts() #looking at listings by neighbourhood
n_count
# Out:
# Other neighborhoods    794
# Capitol Hill           567
# Downtown               530
# Central Area           369
# Queen Anne             295
# Ballard                230
# West Seattle           203
# Rainier Valley         159
# University District    122
# Beacon Hill            118
# Cascade                 89
# Northgate               80
# Delridge                79
# Lake City               67
# Magnolia                61
# Seward Park             44
# Interbay                11
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
df1.shape[0] #needed to generate the numbers after the graph
# Out:
# 3818

# %%
df1['host_id'].unique().all() #checking if a host has more than one listing
# Out:
# True

# %%
plt.figure(figsize=(20,10))
(n_count/df1.shape[0]).plot(kind='bar')
                                         #'Other neighbourhoods' have most listings,
plt.title('Listings by neighbourhood')
plt.savefig('ncount.jpg'); #followed by Capitol Hill, Downtown and Queen Anne

# %%
tic = time.time()
print("So, around {:.1f}% listings are in Other Neighbourhoods.".format(794/3818*100))
print("And, around {:.1f}% listings are in Capitol Hill.".format(567/3818*100))
print("Also,around {:.1f}% listings are in Downtown.".format(530/3818*100))
toc = time.time() - tic
print("And it took me %s seconds to tell you that"%(toc))
# Out:
# So, around 20.8% listings are in Other Neighbourhoods.
# And, around 14.9% listings are in Capitol Hill.
# Also,around 13.9% listings are in Downtown.
# And it took me 0.0004601478576660156 seconds to tell you that

# %%
df1[['neighbourhood_group_cleansed','has_availability',
       'availability_30', 'availability_60', 'availability_90',
       'availability_365','bathrooms','bedrooms','property_type','room_type',]] #looking at availability in neighborhoods
# Out:
#      neighbourhood_group_cleansed has_availability  availability_30  \
# 0                      Queen Anne                t               14
# 1                      Queen Anne                t               13
# 2                      Queen Anne                t                1
# 3                      Queen Anne                t                0
# 4                      Queen Anne                t               30
# ...                           ...              ...              ...
# 3813          Other neighborhoods                t               18
# 3814                 Capitol Hill                t                6
# 3815               Rainier Valley                t               29
# 3816                 Capitol Hill                t               30
# 3817                   Queen Anne                t                7
#
#       availability_60  availability_90  availability_365  bathrooms  bedrooms  \
# 0                  41               71               346        1.0       1.0
# 1                  13               16               291        1.0       1.0
# 2                   6               17               220        4.5       5.0
# 3                   0                0               143        1.0       0.0
# 4                  60               90               365        2.0       3.0
# ...               ...              ...               ...        ...       ...
# 3813               32               32                32        2.0       3.0
# 3814               26               44               273        1.0       1.0
# 3815               59               88                88        1.0       1.0
# 3816               60               90               179        1.0       0.0
# 3817                7                7                 7        1.5       2.0
#
#      property_type        room_type
# 0        Apartment  Entire home/apt
# 1        Apartment  Entire home/apt
# 2            House  Entire home/apt
# 3        Apartment  Entire home/apt
# 4            House  Entire home/apt
# ...            ...              ...
# 3813         House  Entire home/apt
# 3814     Apartment  Entire home/apt
# 3815         House  Entire home/apt
# 3816   Condominium  Entire home/apt
# 3817     Apartment  Entire home/apt
#
# [3818 rows x 10 columns]

# %%
av_count = df1['availability_365'].median() #whats the median availability like in a year?
av_count
# Out:
# 308.0

# %%
df2 = df1.groupby(['neighbourhood_group_cleansed',  #checking availability by neighbourhood
       'availability_365'],as_index=False)['id'].count()
df2.head()
# Out:
#   neighbourhood_group_cleansed  availability_365  id
# 0                      Ballard                 0   2
# 1                      Ballard                 2   2
# 2                      Ballard                 5   1
# 3                      Ballard                11   1
# 4                      Ballard                13   1

# %%
n = df2['neighbourhood_group_cleansed'].value_counts() #unique listings count by neighbourhood
n
# Out:
# Other neighborhoods    255
# Downtown               223
# Capitol Hill           212
# Central Area           169
# Queen Anne             160
# Ballard                121
# West Seattle           111
# Rainier Valley          91
# Beacon Hill             79
# Cascade                 63
# University District     63
# Delridge                47
# Northgate               47
# Lake City               41
# Magnolia                36
# Seward Park             30
# Interbay                 6
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
a = df2['availability_365'].value_counts()
a
# Out:
# 365    17
# 364    15
# 89     15
# 0      15
# 358    14
#        ..
# 210     1
# 214     1
# 224     1
# 225     1
# 299     1
# Name: availability_365, Length: 363, dtype: int64

# %%
df2.shape[0]
# Out:
# 1754

# %%
df2_a = df2.loc[df2['neighbourhood_group_cleansed'] == 'Other neighborhoods',
              ['availability_365']]
df2_a.head() #checking availability of Other neighborhoods
# Out:
#       availability_365
# 1044                 0
# 1045                 1
# 1046                 2
# 1047                 3
# 1048                 4

# %%
other_neigh = df2_a['availability_365'].median()
print("Of the grouped listings, {:.1f}% listings are in Other Neighborhoods.".format(255/1754*100))
print("The median availability annually in Other Neighborhoods is {} days.".format(int(other_neigh)))
# Out:
# Of the grouped listings, 14.5% listings are in Other Neighborhoods.
# The median availability annually in Other Neighborhoods is 175 days.

# %%
df2_b = df2.loc[df2['neighbourhood_group_cleansed'] == 'Downtown', #checking availability annually in Downtown
              ['availability_365']]
df2_b.head()
# Out:
#      availability_365
# 691                 0
# 692                 2
# 693                 3
# 694                 4
# 695                 5

# %%
down_neigh = df2_b['availability_365'].median()
print("Out of the grouped listings, {:.1f}% listings are in Downtown.".format(223/1754*100))
print("The median availability annually in Downtown is {} days.".format(int(down_neigh)))
# Out:
# Out of the grouped listings, 12.7% listings are in Downtown.
# The median availability annually in Downtown is 177 days.

# %%
df2_c = df2.loc[df2['neighbourhood_group_cleansed'] == 'Capitol Hill',
               ['availability_365']]
df2_c.head()
# Out:
#      availability_365
# 200                 0
# 201                 1
# 202                 2
# 203                 4
# 204                 5

# %%
cap_neigh = df2_c['availability_365'].median()
print("Out of the grouped listings, {:.1f}% listings are in Capitol Hill.".format(212/1754*100))
print("The median availability annually in Capitol Hill is {} days.".format(int(cap_neigh)))
# Out:
# Out of the grouped listings, 12.1% listings are in Capitol Hill.
# The median availability annually in Capitol Hill is 175 days.

# %%
tic = time.time()
plt.figure(figsize=(20,10))
n.plot(kind='bar')
plt.savefig('clean_neigh.jpg')
toc = time.time() - tic
print("Time taken to generate 'em bars %s seconds."%(toc))  #after a little cleanup, Other Neighborhoods still top by unique listing counts
# Out:
# Time taken to generate 'em bars 0.20135903358459473 seconds.

# %%
df3 = df1[['neighbourhood_group_cleansed','availability_365','bathrooms','bedrooms',
     'property_type','room_type','beds', 'bed_type', 'square_feet',
       'price', 'weekly_price', 'monthly_price',]]
df3.head()
# Out:
#   neighbourhood_group_cleansed  availability_365  bathrooms  bedrooms  \
# 0                   Queen Anne               346        1.0       1.0
# 1                   Queen Anne               291        1.0       1.0
# 2                   Queen Anne               220        4.5       5.0
# 3                   Queen Anne               143        1.0       0.0
# 4                   Queen Anne               365        2.0       3.0
#
#   property_type        room_type  beds  bed_type  square_feet    price  \
# 0     Apartment  Entire home/apt   1.0  Real Bed          NaN   $85.00
# 1     Apartment  Entire home/apt   1.0  Real Bed          NaN  $150.00
# 2         House  Entire home/apt   7.0  Real Bed          NaN  $975.00
# 3     Apartment  Entire home/apt   2.0  Real Bed          NaN  $100.00
# 4         House  Entire home/apt   3.0  Real Bed          NaN  $450.00
#
#   weekly_price monthly_price
# 0          NaN           NaN
# 1    $1,000.00     $3,000.00
# 2          NaN           NaN
# 3      $650.00     $2,300.00
# 4          NaN           NaN

# %%
tic = time.time()
df3['price'] = df3['price'].str.replace("[$,]", "").astype("float")
df3['weekly_price'] = df3['weekly_price'].str.replace("[$,]", "").astype("float")
df3['monthly_price'] = df3['monthly_price'].str.replace("[$,]", "").astype("float")
toc = time.time() - tic
print("Yo, time taken to do this %s seconds."%(toc)) #convert price data points to float & profile time
# Out:
# Yo, time taken to do this 0.02666616439819336 seconds.
# /Users/sukanto/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/sukanto/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sukanto/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df3.head()
# Out:
#   neighbourhood_group_cleansed  availability_365  bathrooms  bedrooms  \
# 0                   Queen Anne               346        1.0       1.0
# 1                   Queen Anne               291        1.0       1.0
# 2                   Queen Anne               220        4.5       5.0
# 3                   Queen Anne               143        1.0       0.0
# 4                   Queen Anne               365        2.0       3.0
#
#   property_type        room_type  beds  bed_type  square_feet  price  \
# 0     Apartment  Entire home/apt   1.0  Real Bed          NaN   85.0
# 1     Apartment  Entire home/apt   1.0  Real Bed          NaN  150.0
# 2         House  Entire home/apt   7.0  Real Bed          NaN  975.0
# 3     Apartment  Entire home/apt   2.0  Real Bed          NaN  100.0
# 4         House  Entire home/apt   3.0  Real Bed          NaN  450.0
#
#    weekly_price  monthly_price
# 0           NaN            NaN
# 1        1000.0         3000.0
# 2           NaN            NaN
# 3         650.0         2300.0
# 4           NaN            NaN

# %%
df3.isnull().any() #checking null values again
# Out:
# neighbourhood_group_cleansed    False
# availability_365                False
# bathrooms                        True
# bedrooms                         True
# property_type                    True
# room_type                       False
# beds                             True
# bed_type                        False
# square_feet                      True
# price                           False
# weekly_price                     True
# monthly_price                    True
# dtype: bool

# %%
df3_price = df3.fillna(df3[['price','weekly_price','monthly_price']].median()) #imputing prices with median
df3_price.head()
# Out:
#   neighbourhood_group_cleansed  availability_365  bathrooms  bedrooms  \
# 0                   Queen Anne               346        1.0       1.0
# 1                   Queen Anne               291        1.0       1.0
# 2                   Queen Anne               220        4.5       5.0
# 3                   Queen Anne               143        1.0       0.0
# 4                   Queen Anne               365        2.0       3.0
#
#   property_type        room_type  beds  bed_type  square_feet  price  \
# 0     Apartment  Entire home/apt   1.0  Real Bed          NaN   85.0
# 1     Apartment  Entire home/apt   1.0  Real Bed          NaN  150.0
# 2         House  Entire home/apt   7.0  Real Bed          NaN  975.0
# 3     Apartment  Entire home/apt   2.0  Real Bed          NaN  100.0
# 4         House  Entire home/apt   3.0  Real Bed          NaN  450.0
#
#    weekly_price  monthly_price
# 0         650.0         2200.0
# 1        1000.0         3000.0
# 2         650.0         2200.0
# 3         650.0         2300.0
# 4         650.0         2200.0

# %%
df3_price.isnull().any()
# Out:
# neighbourhood_group_cleansed    False
# availability_365                False
# bathrooms                        True
# bedrooms                         True
# property_type                    True
# room_type                       False
# beds                             True
# bed_type                        False
# square_feet                      True
# price                           False
# weekly_price                    False
# monthly_price                   False
# dtype: bool

# %%
df3_a = df3_price.groupby(['neighbourhood_group_cleansed',  
       'price','property_type'],as_index=False).count()

# %%
df3_a
# Out:
#      neighbourhood_group_cleansed  price property_type  availability_365  \
# 0                         Ballard   25.0         House                 1
# 1                         Ballard   35.0         House                 2
# 2                         Ballard   38.0     Apartment                 1
# 3                         Ballard   40.0         House                 1
# 4                         Ballard   45.0         House                 1
# ...                           ...    ...           ...               ...
# 1754                 West Seattle  375.0         House                 1
# 1755                 West Seattle  399.0         House                 1
# 1756                 West Seattle  450.0         House                 1
# 1757                 West Seattle  495.0   Condominium                 1
# 1758                 West Seattle  495.0         House                 1
#
#       bathrooms  bedrooms  room_type  beds  bed_type  square_feet  \
# 0             1         1          1     1         1            0
# 1             2         2          2     2         2            0
# 2             1         1          1     1         1            0
# 3             1         1          1     1         1            0
# 4             1         1          1     1         1            0
# ...         ...       ...        ...   ...       ...          ...
# 1754          1         1          1     1         1            0
# 1755          1         1          1     1         1            0
# 1756          1         1          1     1         1            0
# 1757          1         1          1     1         1            0
# 1758          1         1          1     1         1            0
#
#       weekly_price  monthly_price
# 0                1              1
# 1                2              2
# 2                1              1
# 3                1              1
# 4                1              1
# ...            ...            ...
# 1754             1              1
# 1755             1              1
# 1756             1              1
# 1757             1              1
# 1758             1              1
#
# [1759 rows x 12 columns]

# %%
df3_b = df3_a.groupby(['property_type'])['price'].median() #whats the median prices of properties?
df3_b.head
# Out:
# <bound method NDFrame.head of property_type
# Apartment          109.0
# Bed & Breakfast     99.0
# Boat               150.0
# Bungalow            97.0
# Cabin               95.0
# Camper/RV           90.5
# Chalet              98.5
# Condominium        115.0
# Dorm                39.5
# House              105.0
# Loft               107.5
# Other               85.0
# Tent                50.0
# Townhouse          100.0
# Treehouse           55.0
# Yurt               100.0
# Name: price, dtype: float64>

# %%
plt.figure(figsize=(20,10))
df3_b.plot(kind='bar',color ='#3293a8');
plt.xlabel('Property Type')
plt.ylabel('Price')
plt.savefig('property_prices.jpg') #Boats seem to be the priciest

# %%
df3_price.head()  #dropped the square feet column in an earlier code but mix up happened, oops
# Out:
#   neighbourhood_group_cleansed  availability_365  bathrooms  bedrooms  \
# 0                   Queen Anne               346        1.0       1.0
# 1                   Queen Anne               291        1.0       1.0
# 2                   Queen Anne               220        4.5       5.0
# 3                   Queen Anne               143        1.0       0.0
# 4                   Queen Anne               365        2.0       3.0
#
#   property_type        room_type  beds  bed_type  square_feet  price  \
# 0     Apartment  Entire home/apt   1.0  Real Bed          NaN   85.0
# 1     Apartment  Entire home/apt   1.0  Real Bed          NaN  150.0
# 2         House  Entire home/apt   7.0  Real Bed          NaN  975.0
# 3     Apartment  Entire home/apt   2.0  Real Bed          NaN  100.0
# 4         House  Entire home/apt   3.0  Real Bed          NaN  450.0
#
#    weekly_price  monthly_price
# 0         650.0         2200.0
# 1        1000.0         3000.0
# 2         650.0         2200.0
# 3         650.0         2300.0
# 4         650.0         2200.0

# %%
df3_price.to_csv('clean_combine.csv')

# %%
sns.scatterplot(df3_price['availability_365'],df3_price['price'],
                color="#2ecc71",hue=df3_price['bedrooms']) #yeah well, there are properties with zero bedrooms
plt.xlabel('Annual Availability')
plt.ylabel('Price');

# %%
prop = df3_price[['property_type','price']]
prop
# Out:
#      property_type  price
# 0        Apartment   85.0
# 1        Apartment  150.0
# 2            House  975.0
# 3        Apartment  100.0
# 4            House  450.0
# ...            ...    ...
# 3813         House  359.0
# 3814     Apartment   79.0
# 3815         House   93.0
# 3816   Condominium   99.0
# 3817     Apartment   87.0
#
# [3818 rows x 2 columns]

# %%
prop['property_type'].value_counts()
# Out:
# House              1733
# Apartment          1708
# Townhouse           118
# Condominium          91
# Loft                 40
# Bed & Breakfast      37
# Other                22
# Cabin                21
# Camper/RV            13
# Bungalow             13
# Boat                  8
# Tent                  5
# Treehouse             3
# Dorm                  2
# Chalet                2
# Yurt                  1
# Name: property_type, dtype: int64

# %%
prop.shape[0] #to generate some numbers by property type, as follows
# Out:
# 3818

# %%
tic = time.time()
print("Around {:.1f}% of the listings are apartments.".format(1708/3818*100))
print("Around {:.1f}% of the listings are houses.".format(1733/3818*100))
toc = time.time() - tic
print("And it took me %s seconds to tell you that."%(toc))
# Out:
# Around 44.7% of the listings are apartments.
# Around 45.4% of the listings are houses.
# And it took me 0.0004150867462158203 seconds to tell you that.

# %%
aprt = prop.loc[prop['property_type']=='Apartment']
aprt
# Out:
#      property_type  price
# 0        Apartment   85.0
# 1        Apartment  150.0
# 3        Apartment  100.0
# 8        Apartment   90.0
# 9        Apartment  150.0
# ...            ...    ...
# 3809     Apartment  120.0
# 3811     Apartment   65.0
# 3812     Apartment   95.0
# 3814     Apartment   79.0
# 3817     Apartment   87.0
#
# [1708 rows x 2 columns]

# %%
aprt.to_csv('apartments.csv')

# %%
house = prop.loc[prop['property_type']=='House']
house
# Out:
#      property_type  price
# 2            House  975.0
# 4            House  450.0
# 5            House  120.0
# 6            House   80.0
# 10           House   95.0
# ...            ...    ...
# 3806         House  160.0
# 3808         House  175.0
# 3810         House  154.0
# 3813         House  359.0
# 3815         House   93.0
#
# [1733 rows x 2 columns]

# %%
house.to_csv('house.csv')

# %%
prop.fillna(prop['price']).median()
# Out:
# price    100.0
# dtype: float64

# %%
prop.isnull().any()
# Out:
# property_type     True
# price            False
# dtype: bool

# %%
prop.dropna(subset=['property_type'])
# Out:
#      property_type  price
# 0        Apartment   85.0
# 1        Apartment  150.0
# 2            House  975.0
# 3        Apartment  100.0
# 4            House  450.0
# ...            ...    ...
# 3813         House  359.0
# 3814     Apartment   79.0
# 3815         House   93.0
# 3816   Condominium   99.0
# 3817     Apartment   87.0
#
# [3817 rows x 2 columns]

# %%
prop.isnull().any()
# Out:
# property_type     True
# price            False
# dtype: bool

# %%
ap_price = aprt['price'].value_counts()
ap_price
# Out:
# 100.0    91
# 150.0    84
# 95.0     63
# 110.0    60
# 90.0     57
#          ..
# 232.0     1
# 425.0     1
# 295.0     1
# 365.0     1
# 999.0     1
# Name: price, Length: 196, dtype: int64

# %%
plt.hist(ap_price,bins=10)
plt.ylabel('Price')
plt.title('Apartment Prices'); #most apartment prices are in the USD 150 range
